# %%
import pandas as pd

# %%
ookla_df = pd.read_csv('Ookla_dataset.csv')

# %%
ookla_df.head()
# Out:
#           quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  22133222312322        5227        2449          54      2        2
# 1  22133222330010        9529        3214          44      1        1
# 2  22133222330011        9392        3390          42      1        1
# 3  22133222330013         961         723          50      2        1
# 4  22133222330023        6547        3135          46      5        3
#
#                                             geometry
# 0  POLYGON ((-160.02685546875 70.6435894914449, -...
# 1  POLYGON ((-160.037841796875 70.6417687358462, ...
# 2  POLYGON ((-160.032348632812 70.6417687358462, ...
# 3  POLYGON ((-160.032348632812 70.6399478155463, ...
# 4  POLYGON ((-160.043334960938 70.6363054807905, ...

# %%
ookla_df.tail()
# Out:
#                   quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 4466073  3131120221103101       29047       16266          24      9        1
# 4466074  3131120221103110       34289       31924          18      5        5
# 4466075  3131120300000113        8832        4123          16      4        2
# 4466076  3131120300000300       21775       10919          19     21        1
# 4466077  3301200301201233       10110        5192          11      1        1
#
#                                                   geometry
# 4466073  POLYGON ((169.348754882812 -46.5890690830918, ...
# 4466074  POLYGON ((169.354248046875 -46.5890690830918, ...
# 4466075  POLYGON ((170.194702148438 -46.0770413127077, ...
# 4466076  POLYGON ((170.17822265625 -46.0884717957759, 1...
# 4466077  POLYGON ((114.318237304688 -71.1434194049621, ...

# %%
ookla_df.shape
# Out:
# (4466078, 7)

# %%
ookla_df.size
# Out:
# 31262546

# %%
len(ookla_df)
# Out:
# 4466078

# %%
ookla_df.columns
# Out:
# Index(['quadkey', 'avg_d_kbps', 'avg_u_kbps', 'avg_lat_ms', 'tests', 'devices',
#        'geometry'],
#       dtype='object')

# %%
ookla_df.dtypes
# Out:
# quadkey        int64
# avg_d_kbps     int64
# avg_u_kbps     int64
# avg_lat_ms     int64
# tests          int64
# devices        int64
# geometry      object
# dtype: object

# %%
ookla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4466078 entries, 0 to 4466077
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   quadkey     int64
#  1   avg_d_kbps  int64
#  2   avg_u_kbps  int64
#  3   avg_lat_ms  int64
#  4   tests       int64
#  5   devices     int64
#  6   geometry    object
# dtypes: int64(6), object(1)
# memory usage: 238.5+ MB

# %%
ookla_df.describe()
# Out:
#             quadkey    avg_d_kbps    avg_u_kbps    avg_lat_ms         tests  \
# count  4.466078e+06  4.466078e+06  4.466078e+06  4.466078e+06  4.466078e+06
# mean   8.998742e+14  6.776345e+04  3.009203e+04  3.479425e+01  1.602160e+01
# std    6.872253e+14  7.621750e+04  4.964603e+04  1.129510e+02  4.239126e+01
# min    2.213322e+13  1.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00
# 25%    3.131023e+14  1.458200e+04  4.749000e+03  1.000000e+01  1.000000e+00
# 50%    1.201223e+15  3.994300e+04  1.268200e+04  1.600000e+01  4.000000e+00
# 75%    1.221122e+15  9.520400e+04  3.196100e+04  2.800000e+01  1.400000e+01
# max    3.301200e+15  9.420030e+05  9.433090e+05  6.005000e+04  8.568000e+03
#
#             devices
# count  4.466078e+06
# mean   4.411707e+00
# std    9.750654e+00
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    4.000000e+00
# max    1.441000e+03

# %%
speed_d = ookla_df['avg_d_kbps']
speed_d.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
speed_u = ookla_df['avg_u_kbps']
speed_u.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
latency = ookla_df['avg_lat_ms']
latency.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sample = speed_d.sample(500)
sample.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sample = speed_u.sample(500)
sample.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sample = latency.sample(500)
sample.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ookla_df.isnull().sum()
# Out:
# quadkey       0
# avg_d_kbps    0
# avg_u_kbps    0
# avg_lat_ms    0
# tests         0
# devices       0
# geometry      0
# dtype: int64

# %%
ookla_df.isna().sum()
# Out:
# quadkey       0
# avg_d_kbps    0
# avg_u_kbps    0
# avg_lat_ms    0
# tests         0
# devices       0
# geometry      0
# dtype: int64

# %%
ookla_df.duplicated().sum()
# Out:
# 0

# %%
ookla_df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'quadkey'}>,
#         <Axes: title={'center': 'avg_d_kbps'}>],
#        [<Axes: title={'center': 'avg_u_kbps'}>,
#         <Axes: title={'center': 'avg_lat_ms'}>],
#        [<Axes: title={'center': 'tests'}>,
#         <Axes: title={'center': 'devices'}>]], dtype=object)
